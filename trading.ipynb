# %%
#import firstStrategy
#firstStrategy.trading_bot(1063)

# %%
import strategies
import warnings
warnings.filterwarnings('ignore')

# %%
strategies.SMAxtoy('ETH-USD', 20, 50, 50)
strategies.SMAxtoy('BTC-USD', 20, 50, 1000)
strategies.SMAxtoy('AAPL', 20, 50, 5)
strategies.SMAxtoy('TSLA', 20, 50, 15)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
strategies.SMAxtoy('ETH-USD', 50, 100, 50)
strategies.SMAxtoy('BTC-USD', 50, 100, 1000)
strategies.SMAxtoy('AAPL', 50, 100, 5)
strategies.SMAxtoy('TSLA', 50, 100, 15)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
strategies.BoillingBands('ETH-USD', 100)
strategies.BoillingBands('BTC-USD', 2000)
strategies.BoillingBands('AAPL', 5)
strategies.BoillingBands('TSLA', 15)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
strategies.RSI('ETH-USD', 8)
strategies.RSI('BTC-USD', -12)
strategies.RSI('AAPL', 10)
strategies.RSI('TSLA', 15)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
